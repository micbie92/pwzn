# %% [markdown]
# # Wyjaśnienie

# %% [markdown]
# Dostajecie teraz dane, bardzo podobne do takich na których pracuje się w  "prawdziwej nauce" (w takiej formie dostałem kiedyś prawdziwe dane pomiarowe).
#
# Dane dotyczą poziomów radionuklidów w powietrzu przy gruntowym, są to dość trudne pomiary do przeprowadzenia, ponieważ rejestruje się bardzo niskie dawki (aktywności w powietrzu są rzędu mikrobekereli). Procedura pomiarowa wygląda (z grubsza) tak:
#
# * Przepuszczamy powierze pompowane przez wysokowydajną pompę, przez płachtę filtru przez tydzień.
# * Prasujemy filtr
# * Zbieramy spektrum gamma
# * Po kilku obliczeniach (uwzględniających okres półtrwania niektórych nuklidów) otrzymujemy aktywność.
#
#
# Dane które otrzymaliście są wygenerowane :)

# %% [markdown]
# Dane są w pliku: "data.csv" w tym katalogu.

# %% [markdown]
# # Zadanie 1

# %% [markdown]
# Teraz zaimportuj pandas, oraz zainicjalizuj matplotlib:

# %%
import pandas as pd
from matplotlib import pylab

# %% [markdown]
# Załaduj plik z danymi (dobrym pomysłem jest obejrzenie go w arkuszu kalkulacyjnym)

# %%
data = pd.read_csv('data.csv', header=1)
data
# Out:
#       Rok  Tyg  Dust   7Be  137Cs  210Pb   40K  22Na  134Cs
# 0    2010    1   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 1     NaN    2   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 2     NaN    3   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 3     NaN    4   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 4     NaN    5   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 5     NaN    6   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 6     NaN    7   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 7     NaN    8   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 8     NaN    9   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 9     NaN   10   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 10    NaN   11   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 11    NaN   12   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 12    NaN   13   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 13    NaN   14   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 14    NaN   15   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 15    NaN   16   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 16    NaN   17   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 17    NaN   18   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 18    NaN   19   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 19    NaN   20   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 20    NaN   21   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 21    NaN   22   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 22    NaN   23   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 23    NaN   24   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 24    NaN   25   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 25    NaN   26   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 26    NaN   27   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 27    NaN   28   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 28    NaN   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 29    NaN   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# ..    ...  ...   ...   ...    ...    ...   ...   ...    ...
# 230   NaN   23     6   488  0.713   52.5  2.34  4.84    NaN
# 231   NaN   24    16  1584  0.429  106.5  8.52  3.73    NaN
# 232   NaN   25    39  1430  0.729   76.7  6.73  9.24    NaN
# 233   NaN   26    43  1082  0.685   67.3  7.71  9.82    NaN
# 234   NaN   27    32   486  0.348   49.4  6.77  4.12    NaN
# 235   NaN   28    11  1444  0.401   52.1  6.40  6.00    NaN
# 236   NaN   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 237   NaN   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 238   NaN   31   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 239   NaN   32   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 240   NaN   33   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 241   NaN   34   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 242   NaN   35   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 243   NaN   36   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 244   NaN   37   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 245   NaN   38   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 246   NaN   39   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 247   NaN   40   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 248   NaN   41   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 249   NaN   42   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 250   NaN   43   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 251   NaN   44   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 252   NaN   45   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 253   NaN   46   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 254   NaN   47   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 255   NaN   48   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 256   NaN   49   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 257   NaN   50   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 258   NaN   51   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 259   NaN   52   NaN   NaN    NaN    NaN   NaN   NaN    NaN
#
# [260 rows x 9 columns]

# %% [markdown]
# ### Określenie dat

# %% [markdown]
# W pliku pomiary nie mają dat, ale rok i tydzień dokonania pomiaru (w pomiarach radionuklidów w powietrzu przez tydzień zbiera się radionuklidy na filtrze).
#
# Zauważcie że w pliku w wierszu z rokiem nie ma wartości w każdym wierszu. Uzupełnij brakujące dane.

# %%
data['Rok'] = data['Rok'].fillna(method='pad')
data
# Out:
#       Rok  Tyg  Dust   7Be  137Cs  210Pb   40K  22Na  134Cs
# 0    2010    1   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 1    2010    2   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 2    2010    3   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 3    2010    4   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 4    2010    5   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 5    2010    6   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 6    2010    7   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 7    2010    8   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 8    2010    9   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 9    2010   10   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 10   2010   11   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 11   2010   12   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 12   2010   13   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 13   2010   14   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 14   2010   15   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 15   2010   16   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 16   2010   17   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 17   2010   18   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 18   2010   19   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 19   2010   20   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 20   2010   21   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 21   2010   22   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 22   2010   23   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 23   2010   24   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 24   2010   25   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 25   2010   26   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 26   2010   27   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 27   2010   28   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 28   2010   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 29   2010   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# ..    ...  ...   ...   ...    ...    ...   ...   ...    ...
# 230  2014   23     6   488  0.713   52.5  2.34  4.84    NaN
# 231  2014   24    16  1584  0.429  106.5  8.52  3.73    NaN
# 232  2014   25    39  1430  0.729   76.7  6.73  9.24    NaN
# 233  2014   26    43  1082  0.685   67.3  7.71  9.82    NaN
# 234  2014   27    32   486  0.348   49.4  6.77  4.12    NaN
# 235  2014   28    11  1444  0.401   52.1  6.40  6.00    NaN
# 236  2014   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 237  2014   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 238  2014   31   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 239  2014   32   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 240  2014   33   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 241  2014   34   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 242  2014   35   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 243  2014   36   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 244  2014   37   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 245  2014   38   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 246  2014   39   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 247  2014   40   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 248  2014   41   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 249  2014   42   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 250  2014   43   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 251  2014   44   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 252  2014   45   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 253  2014   46   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 254  2014   47   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 255  2014   48   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 256  2014   49   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 257  2014   50   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 258  2014   51   NaN   NaN    NaN    NaN   NaN   NaN    NaN
# 259  2014   52   NaN   NaN    NaN    NaN   NaN   NaN    NaN
#
# [260 rows x 9 columns]

# %% [markdown]
# Teraz przekonwertuj zawartość kolumny Rok do liczb stałoprzeninkowych. To samo zrób z kolumną Tyg

# %%
data[['Rok', 'Tyg']] = data[['Rok', 'Tyg']].astype(int)
data.dtypes
# Out:
# Rok        int64
# Tyg        int64
# Dust     float64
# 7Be      float64
# 137Cs    float64
# 210Pb    float64
# 40K      float64
# 22Na     float64
# 134Cs    float64
# dtype: object

# %% [markdown]
# Dodaj do ramki pole Data, które będzie zawierać datę pomiaru. Datę pomiaru wyznaczasz z roku i numeru tygodnia (wg. kalendzarza ISO). Przeliczenie roku i tygodnia na datę pomiaru wykonaj za pomocą dostarczonej funkcji.
#
# **Uwaga** tego nie da się zwektoryzować, proszę po prostu przeiterować po poszczególnych wierszach wybranych kolumn.

# %%
from datetime import date, timedelta
def week_start_date(year, week, dow=0):    
    """
    :param int year: Numer roku
    :param int week: Numer tygodnia w roku 
    :param int dow: Funkcja ta zwraca datę, zwróci datę dnia o indeksie dow, zero oznacza poniedziałek, jeden wtorek itp. 
    """
    # http://stackoverflow.com/a/1287862/7918
    d = date(year, 1, 1)    
    delta_days = d.isoweekday() - 1
    delta_weeks = week
    if year == d.isocalendar()[0]:
        delta_weeks -= 1
    delta = timedelta(days=-delta_days+dow, weeks=delta_weeks)
    return d + delta

# %%
data['Data'] = [week_start_date(y,int(w)) for y,w in zip(data.Rok, data.Tyg) ]
data
# Out:
#       Rok  Tyg  Dust   7Be  137Cs  210Pb   40K  22Na  134Cs        Data
# 0    2010    1   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-01-04
# 1    2010    2   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-01-11
# 2    2010    3   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-01-18
# 3    2010    4   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-01-25
# 4    2010    5   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-02-01
# 5    2010    6   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-02-08
# 6    2010    7   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-02-15
# 7    2010    8   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-02-22
# 8    2010    9   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-03-01
# 9    2010   10   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-03-08
# 10   2010   11   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-03-15
# 11   2010   12   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-03-22
# 12   2010   13   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-03-29
# 13   2010   14   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-04-05
# 14   2010   15   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-04-12
# 15   2010   16   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-04-19
# 16   2010   17   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-04-26
# 17   2010   18   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-05-03
# 18   2010   19   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-05-10
# 19   2010   20   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-05-17
# 20   2010   21   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-05-24
# 21   2010   22   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-05-31
# 22   2010   23   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-06-07
# 23   2010   24   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-06-14
# 24   2010   25   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-06-21
# 25   2010   26   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-06-28
# 26   2010   27   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-07-05
# 27   2010   28   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-07-12
# 28   2010   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-07-19
# 29   2010   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2010-07-26
# ..    ...  ...   ...   ...    ...    ...   ...   ...    ...         ...
# 230  2014   23     6   488  0.713   52.5  2.34  4.84    NaN  2014-06-02
# 231  2014   24    16  1584  0.429  106.5  8.52  3.73    NaN  2014-06-09
# 232  2014   25    39  1430  0.729   76.7  6.73  9.24    NaN  2014-06-16
# 233  2014   26    43  1082  0.685   67.3  7.71  9.82    NaN  2014-06-23
# 234  2014   27    32   486  0.348   49.4  6.77  4.12    NaN  2014-06-30
# 235  2014   28    11  1444  0.401   52.1  6.40  6.00    NaN  2014-07-07
# 236  2014   29   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-07-14
# 237  2014   30   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-07-21
# 238  2014   31   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-07-28
# 239  2014   32   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-08-04
# 240  2014   33   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-08-11
# 241  2014   34   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-08-18
# 242  2014   35   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-08-25
# 243  2014   36   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-09-01
# 244  2014   37   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-09-08
# 245  2014   38   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-09-15
# 246  2014   39   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-09-22
# 247  2014   40   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-09-29
# 248  2014   41   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-10-06
# 249  2014   42   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-10-13
# 250  2014   43   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-10-20
# 251  2014   44   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-10-27
# 252  2014   45   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-11-03
# 253  2014   46   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-11-10
# 254  2014   47   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-11-17
# 255  2014   48   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-11-24
# 256  2014   49   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-12-01
# 257  2014   50   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-12-08
# 258  2014   51   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-12-15
# 259  2014   52   NaN   NaN    NaN    NaN   NaN   NaN    NaN  2014-12-22
#
# [260 rows x 10 columns]

# %% [markdown]
# Ustaw kolumnę "Date" tak by była indeksem Twojej ramki.

# %%
data.set_index('Data', inplace=True)

# %% [markdown]
# Wyświetl poziomy pyłu (kolumna dust) oraz Berylu (7Be)

# %%
data.Dust[data.Dust.isnull() == False]
# Out:
# Data
# 2010-08-16     5
# 2010-08-23    61
# 2010-08-30    30
# 2010-09-06    43
# 2010-09-13    13
# 2010-09-20    58
# 2010-09-27    19
# 2010-10-04    56
# 2010-10-11     8
# 2010-10-18    16
# 2010-10-25    25
# 2010-11-01     0
# 2010-11-08    55
# 2010-11-15    12
# 2010-11-22    28
# ...
# 2014-03-31     42
# 2014-04-07     61
# 2014-04-14     37
# 2014-04-21     28
# 2014-04-28      7
# 2014-05-05     14
# 2014-05-12     18
# 2014-05-19    122
# 2014-05-26     41
# 2014-06-02      6
# 2014-06-09     16
# 2014-06-16     39
# 2014-06-23     43
# 2014-06-30     32
# 2014-07-07     11
# Name: Dust, Length: 190, dtype: float64

# %%
data['7Be'][data['7Be'].isnull() == False]
# Out:
# Data
# 2010-08-16    1308
# 2010-08-23    1232
# 2010-08-30     336
# 2010-09-06    1198
# 2010-09-13     940
# 2010-09-20     754
# 2010-09-27     688
# 2010-10-04     736
# 2010-10-11     618
# 2010-10-18     944
# 2010-10-25     704
# 2010-11-01     742
# 2010-11-08     468
# 2010-11-15     626
# 2010-11-22     466
# ...
# 2014-03-31    1162
# 2014-04-07    1414
# 2014-04-14     768
# 2014-04-21     982
# 2014-04-28    1190
# 2014-05-05     776
# 2014-05-12    1560
# 2014-05-19     434
# 2014-05-26    1606
# 2014-06-02     488
# 2014-06-09    1584
# 2014-06-16    1430
# 2014-06-23    1082
# 2014-06-30     486
# 2014-07-07    1444
# Name: 7Be, Length: 188, dtype: float64

# %% [markdown]
# ### Średnie miesięczne

# %% [markdown]
# Wyznacz średnie miesięczne poziomów zanieczyszczeń. W tym celu musisz:
#
# *Rozwiązanie nieładne*
#
# 1. Dodać do ramki kolumnę month, która wskasuje miesiąc danego pomiaru.
# 2. Odpalić group_by na miesiącu
# 3. Policzyć średnią
#
# *Rozwiązanie ładne*
#
# 1. Ustawić kolumnę Date jako indeks ramki (musi być typu pd.DatetimeIndex),
#    patrz: http://stackoverflow.com/q/17328655/7918
# 2. użyć df.resample

# %%
data.set_index(pd.DatetimeIndex(data.index), inplace=True)
data.resample('M')
# Out:
#                Rok   Tyg       Dust          7Be     137Cs      210Pb  \
# 2010-01-31  2010.0   2.5        NaN          NaN       NaN        NaN
# 2010-02-28  2010.0   6.5        NaN          NaN       NaN        NaN
# 2010-03-31  2010.0  11.0        NaN          NaN       NaN        NaN
# 2010-04-30  2010.0  15.5        NaN          NaN       NaN        NaN
# 2010-05-31  2010.0  20.0        NaN          NaN       NaN        NaN
# 2010-06-30  2010.0  24.5        NaN          NaN       NaN        NaN
# 2010-07-31  2010.0  28.5        NaN          NaN       NaN        NaN
# 2010-08-31  2010.0  33.0  32.000000   958.666667  0.523333  61.233333
# 2010-09-30  2010.0  37.5  33.250000   895.000000  0.414750  53.475000
# 2010-10-31  2010.0  41.5  26.250000   750.500000  0.431750  44.600000
# 2010-11-30  2010.0  46.0  27.400000   570.400000  0.270400  34.280000
# 2010-12-31  2010.0  50.5  55.750000   488.000000  0.278750  29.575000
# 2011-01-31  2011.0   3.0  28.800000   563.200000  0.346800  32.120000
# 2011-02-28  2011.0   7.5  16.750000   679.000000  0.291500  33.650000
# 2011-03-31  2011.0  11.5  42.500000   956.500000  0.426250  41.325000
# 2011-04-30  2011.0  15.5  52.500000   831.500000  0.372500  44.975000
# 2011-05-31  2011.0  20.0  55.600000  1186.800000  0.471200  58.820000
# 2011-06-30  2011.0  24.5  23.500000  1324.500000  0.465500  70.250000
# 2011-07-31  2011.0  28.5  33.000000  1165.000000  0.532750  43.350000
# 2011-08-31  2011.0  33.0  21.000000   871.200000  0.655400  47.840000
# 2011-09-30  2011.0  37.5  56.750000  1196.500000  0.446250  58.925000
# 2011-10-31  2011.0  42.0  21.200000   963.200000  0.358200  38.640000
# 2011-11-30  2011.0  46.5  16.500000   609.500000  0.416750  34.200000
# 2011-12-31  2011.0  50.5  43.000000   586.000000  0.245250  27.650000
# 2012-01-31  2012.0   3.0  47.000000   532.800000  0.315000  27.980000
# 2012-02-29  2012.0   7.5  20.500000   857.000000  0.368250  39.350000
# 2012-03-31  2012.0  11.5  28.000000  1047.000000  0.391000  53.125000
# 2012-04-30  2012.0  16.0  31.800000  1014.500000  0.474200  44.540000
# 2012-05-31  2012.0  20.5  39.750000  1283.500000  0.532250  57.975000
# 2012-06-30  2012.0  24.5  62.750000  1538.500000  0.731250  65.300000
# 2012-07-31  2012.0  29.0  41.400000  1029.200000  0.629200  80.720000
# 2012-08-31  2012.0  33.5  36.500000   872.500000  0.491000  57.725000
# 2012-09-30  2012.0  37.5   7.750000   706.666667  0.572500  59.100000
# 2012-10-31  2012.0  42.0  31.400000   703.600000  0.415800  44.040000
# 2012-11-30  2012.0  46.5  21.750000   788.500000  0.235000  29.925000
# 2012-12-31  2012.2  40.6  37.600000   395.600000  0.269800  28.600000
# 2013-01-31  2013.0   3.5  21.250000   564.500000  0.298000  28.900000
# 2013-02-28  2013.0   7.5  22.750000   660.500000  0.406000  32.975000
# 2013-03-31  2013.0  11.5  39.333333   818.000000  0.458000  33.500000
# 2013-04-30  2013.0  16.0        NaN          NaN       NaN        NaN
# 2013-05-31  2013.0  20.5        NaN          NaN       NaN        NaN
# 2013-06-30  2013.0  24.5  62.000000  1728.000000  0.200000  91.700000
# 2013-07-31  2013.0  29.0  49.200000  1033.600000  0.502000  71.960000
# 2013-08-31  2013.0  33.5  43.500000   798.500000  0.660333  62.000000
# 2013-09-30  2013.0  38.0  30.400000   856.400000  0.423000  46.620000
# 2013-10-31  2013.0  42.5  51.666667   653.500000  0.431750  22.750000
# 2013-11-30  2013.0  46.5  26.750000   578.000000  0.300750  31.233333
# 2013-12-31  2013.2  40.6  36.400000   516.800000  0.290600  30.320000
# 2014-01-31  2014.0   3.5  28.500000   577.500000  0.282750  38.225000
# 2014-02-28  2014.0   7.5  19.750000   720.500000  0.257333  34.675000
# 2014-03-31  2014.0  12.0  27.200000   921.200000  0.435200  34.140000
# 2014-04-30  2014.0  16.5  33.250000  1088.500000  0.671250  53.800000
# 2014-05-31  2014.0  20.5  48.750000  1094.000000  0.733333  51.050000
# 2014-06-30  2014.0  25.0  27.200000  1014.000000  0.580800  70.480000
# 2014-07-31  2014.0  29.5  11.000000  1444.000000  0.401000  52.100000
# 2014-08-31  2014.0  33.5        NaN          NaN       NaN        NaN
# 2014-09-30  2014.0  38.0        NaN          NaN       NaN        NaN
# 2014-10-31  2014.0  42.5        NaN          NaN       NaN        NaN
# 2014-11-30  2014.0  46.5        NaN          NaN       NaN        NaN
# 2014-12-31  2014.0  50.5        NaN          NaN       NaN        NaN
#
#                  40K      22Na       134Cs
# 2010-01-31       NaN       NaN         NaN
# 2010-02-28       NaN       NaN         NaN
# 2010-03-31       NaN       NaN         NaN
# 2010-04-30       NaN       NaN         NaN
# 2010-05-31       NaN       NaN         NaN
# 2010-06-30       NaN       NaN         NaN
# 2010-07-31       NaN       NaN         NaN
# 2010-08-31  4.713333  5.576667         NaN
# 2010-09-30  4.853333  3.582500         NaN
# 2010-10-31  3.310000  4.977500         NaN
# 2010-11-30  3.054000  3.816000         NaN
# 2010-12-31  2.987500  1.590000         NaN
# 2011-01-31  2.924000  2.554000         NaN
# 2011-02-28  4.197500  3.497500         NaN
# 2011-03-31  4.862500  4.807500         NaN
# 2011-04-30  4.287500  4.452500         NaN
# 2011-05-31  5.386000  6.574000         NaN
# 2011-06-30  7.062500  6.030000         NaN
# 2011-07-31  6.047500  5.955000         NaN
# 2011-08-31  6.858000  5.370000         NaN
# 2011-09-30  3.970000  5.375000         NaN
# 2011-10-31  3.200000  4.044000         NaN
# 2011-11-30  2.590000  3.107500         NaN
# 2011-12-31  2.675000  3.080000         NaN
# 2012-01-31  2.172000  3.020000         NaN
# 2012-02-29  4.205000  3.357500         NaN
# 2012-03-31  4.887500  4.962500         NaN
# 2012-04-30  4.884000  5.930000         NaN
# 2012-05-31  5.430000  5.317500         NaN
# 2012-06-30  6.150000  8.065000         NaN
# 2012-07-31  4.624000  6.866000         NaN
# 2012-08-31  5.700000  6.242500         NaN
# 2012-09-30  5.602500  4.130000         NaN
# 2012-10-31  2.496000  4.044000         NaN
# 2012-11-30  3.660000  2.777500         NaN
# 2012-12-31  2.534000  2.590000         NaN
# 2013-01-31  2.510000  3.662500  424.000000
# 2013-02-28  3.892500  3.165000  450.000000
# 2013-03-31  3.420000  3.856667         NaN
# 2013-04-30       NaN       NaN         NaN
# 2013-05-31       NaN       NaN         NaN
# 2013-06-30  4.710000  5.880000         NaN
# 2013-07-31  4.342000  5.526000         NaN
# 2013-08-31  5.360000  4.875000  518.666667
# 2013-09-30  5.478000  4.270000  436.000000
# 2013-10-31  2.562500  4.073333         NaN
# 2013-11-30  3.313333  2.976667         NaN
# 2013-12-31  3.030000  2.806000         NaN
# 2014-01-31  2.777500  2.742500         NaN
# 2014-02-28  3.317500  3.175000         NaN
# 2014-03-31  4.030000  4.300000         NaN
# 2014-04-30  5.077500  5.165000  349.750000
# 2014-05-31  5.842500  5.872500         NaN
# 2014-06-30  6.414000  6.350000         NaN
# 2014-07-31  6.400000  6.000000         NaN
# 2014-08-31       NaN       NaN         NaN
# 2014-09-30       NaN       NaN         NaN
# 2014-10-31       NaN       NaN         NaN
# 2014-11-30       NaN       NaN         NaN
# 2014-12-31       NaN       NaN         NaN

# %% [markdown]
# ### Zapis wyników

# %% [markdown]
# Zapisz wyniki tygodniowe do jakiegoś formatu:

# %%
with open('data1.html','w') as f:
    f.write(data.to_html())
